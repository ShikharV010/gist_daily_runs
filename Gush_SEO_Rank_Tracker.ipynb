# %% [markdown]
# <a href="https://colab.research.google.com/github/ShikharV010/gist_daily_runs/blob/main/Gush_SEO_Rank_Tracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas sqlalchemy psycopg2-binary python-dateutil gspread oauth2client
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.12/dist-packages (2.0.45)
# Requirement already satisfied: psycopg2-binary in /usr/local/lib/python3.12/dist-packages (2.9.11)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (2.9.0.post0)
# Requirement already satisfied: gspread in /usr/local/lib/python3.12/dist-packages (6.2.1)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.12/dist-packages (4.1.3)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy) (4.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil) (1.17.0)
# Requirement already satisfied: google-auth>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from gspread) (2.43.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from gspread) (1.2.2)
# Requirement already satisfied: httplib2>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from oauth2client) (0.31.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.12/dist-packages (from oauth2client) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.12/dist-packages (from oauth2client) (0.4.2)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from oauth2client) (4.9.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.12.0->gspread) (6.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (2.0.0)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in /usr/local/lib/python3.12/dist-packages (from httplib2>=0.9.1->oauth2client) (3.2.5)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.3.1)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2025.11.12)

# %%
# --- CONFIG ---
import os
import pandas as pd
from sqlalchemy import create_engine, text

DB_URL = "postgresql+psycopg2://airbyte_user:airbyte_user_password@gw-rds-prod.celzx4qnlkfp.us-east-1.rds.amazonaws.com:5432/gw_prod"

SCHEMA_GSC  = "airbyte_ingestion"
TBL_GSC_PQD = "gush_gsc_page_query_daily"  # (kept if you still need query-level)
TBL_GSC_PD  = "gush_gsc_page_daily"        # <-- new: page-level table

SCHEMA_DICT = "airbyte_ingestion"
TABLE_DICT  = "gtm_seo_gush_seo_pages"
# TABLE_BLOG_DICT = '"seo_tracker_BlogType"'

engine = create_engine(DB_URL)

# %%
# --- READ GSC: page_query_daily ---
with engine.connect() as con:
    gsc_pqd_sql = text(f"""
        SELECT
            date::date          AS date,
            page                AS page,
            query               AS query,
            clicks::bigint      AS clicks,
            impressions::bigint AS impressions,
            ctr::numeric        AS ctr,
            position::numeric   AS position
        FROM {SCHEMA_GSC}.{TBL_GSC_PQD}
        WHERE date IS NOT NULL
    """)
    gsc_page_query_daily_df = pd.read_sql(gsc_pqd_sql, con)

# --- READ GSC: page_daily (use this for page-level performance) ---
with engine.connect() as con:
    gsc_pd_sql = text(f"""
        SELECT
            date::date          AS date,
            page                AS page,
            clicks::bigint      AS clicks,
            impressions::bigint AS impressions
        FROM {SCHEMA_GSC}.{TBL_GSC_PD}
        WHERE date IS NOT NULL
    """)
    gsc_page_daily_df = pd.read_sql(gsc_pd_sql, con)

# --- READ Pages/Keywords (only the columns you need; exact hero_url strings) ---
with engine.connect() as con:
    dict_sql = text(f"""
        SELECT
            primary_keyword,
            secondary_keyword,
            hero_url,
            volume,
            last_updated_date,
            status
        FROM {SCHEMA_DICT}.{TABLE_DICT}
        WHERE hero_url IS NOT NULL
          AND hero_url <> ''
          AND hero_url <> 'New'
          AND hero_url <> '\\'
    """)
    dict_raw_df = pd.read_sql(dict_sql, con)

#display(gsc_page_daily_df.head(3))
#display(dict_raw_df.head(3))

# with engine.connect() as con:
#     dict_blog_sql = text(f"""
#         SELECT DISTINCT blog_url,
#               regexp_replace(blog_url, '^https?://[^/]+', '') AS updated_url,
#               blog_type
#           FROM airbyte_ingestion."seo_tracker_BlogType"
#     """)
#     dict_blogtype_df = pd.read_sql(dict_blog_sql, con)


with engine.connect() as con:
    dict_blog_sql = text("""
        SELECT blog_url,
               regexp_replace(blog_url, '^https?://[^/]+', '') AS updated_url,
               blog_type
        FROM airbyte_ingestion."gush_blogs_Monish"

        UNION

        SELECT blog_url,
               regexp_replace(blog_url, '^https?://[^/]+', '') AS updated_url,
               blog_type
        FROM airbyte_ingestion."gush_blogs_Preksha"
    """)

    dict_blogtype_df = pd.read_sql(dict_blog_sql, con)

# %%
display(dict_blogtype_df)
# Out:
#                                               blog_url  \
# 0         https://www.gushwork.ai/blog/locksmith-leads
# 1    https://www.gushwork.ai/blog/affordable-seo-fo...
# 2    https://www.gushwork.ai/blog/manufacturing-sal...
# 3    https://www.gushwork.ai/blog/b2b-content-writi...
# 4    https://www.gushwork.ai/blog/best-seo-software...
# ..                                                 ...
# 254  https://www.gushwork.ai/blog/content-marketing...
# 255  https://www.gushwork.ai/blog/guerrilla-marketi...
# 256  https://www.gushwork.ai/trade-show-roi-calculator
# 257  https://www.gushwork.ai/blog/window-and-door-c...
# 258  https://www.gushwork.ai/blog/landscaping-marke...
#
#                                            updated_url blog_type
# 0                                /blog/locksmith-leads     scale
# 1    /blog/affordable-seo-for-hvac-contractors-stra...     scale
# 2                   /blog/manufacturing-sales-training     scale
# 3            /blog/b2b-content-writing-beginners-guide     scale
# 4                 /blog/best-seo-software-for-agencies     scale
# ..                                                 ...       ...
# 254           /blog/content-marketing-for-distributors     scale
# 255    /blog/guerrilla-marketing-ideas-for-trade-shows     scale
# 256                         /trade-show-roi-calculator     scale
# 257         /blog/window-and-door-contractor-marketing     scale
# 258                        /blog/landscaping-marketing     scale
#
# [259 rows x 3 columns]

# %% [markdown]
# GET QUERY AND PAGE PERFORMANCE

# %%
# -*- coding: utf-8 -*-
"""
WEEKLY SEO RANK TRACKING PIPELINE
---------------------------------
This script fetches Google rankings for each (secondary_keyword, hero_url)
and stores them in a long-format history table in PostgreSQL.

Key features:
- Does NOT modify or replace any existing SEO tables.
- Creates and maintains its own history table: gist.gush_rank_history.
- Appends new rows each run (one row per keyword per date).
- Allows filtering to only "core" blogs for testing.
"""

import os
import pandas as pd
from sqlalchemy import create_engine, text

# ─────────────────────────────────────────────────────────────
# CONFIG
# ─────────────────────────────────────────────────────────────
DB_URL = os.getenv(
    "DB_URL",
    "postgresql+psycopg2://airbyte_user:airbyte_user_password@"
    "gw-rds-prod.celzx4qnlkfp.us-east-1.rds.amazonaws.com:5432/gw_prod"
)

SCHEMA_GSC = "airbyte_ingestion"
TABLE_GSC  = "gush_gsc_page_query_daily"

SCHEMA_DICT = "airbyte_ingestion"
TABLE_DICT  = "gtm_seo_gush_seo_pages"

df_keywords = dict_raw_df[["primary_keyword", "secondary_keyword", "hero_url"]]

df_keywords.columns = df_keywords.columns.str.lower()
df_keywords = df_keywords.drop_duplicates()

# %%
df_keywords.head()
# Out:
#                primary_keyword  \
# 0  marketing for manufacturing
# 1  marketing for manufacturing
# 2  marketing for manufacturing
# 3  marketing for manufacturing
# 4  marketing for manufacturing
#
#                                  secondary_keyword  \
# 0                      marketing for manufacturing
# 1  marketing solutions for manufacturing companies
# 2     marketing strategy for manufacturing company
# 3             marketing to manufacturing companies
# 4                 marketing manufacturing strategy
#
#                                             hero_url
# 0  https://www.gushwork.ai/blog/b2b-manufacturing...
# 1  https://www.gushwork.ai/blog/b2b-manufacturing...
# 2  https://www.gushwork.ai/blog/b2b-manufacturing...
# 3  https://www.gushwork.ai/blog/b2b-manufacturing...
# 4  https://www.gushwork.ai/blog/b2b-manufacturing...

# %%
# Normalize formatting
dict_blogtype_df.columns = dict_blogtype_df.columns.str.lower()
dict_blogtype_df['blog_type'] = dict_blogtype_df['blog_type'].str.lower()

# Rename updated_url -> hero_url to match wide table
dict_blogtype_df = dict_blogtype_df.rename(columns={"blog_url": "hero_url"})

# %%
# Merge onto final output
final_long_df = df_keywords.merge(
    dict_blogtype_df[['hero_url', 'blog_type']],
    on='hero_url',
    how='left'
)

# Filter only scale blogs --> Remove this filter once the pipeline is set
# final_long_df = final_long_df[final_long_df['blog_type'] == 'scale']

# %%
# Preserve the original copy for validation purpose:
final_long_df_original = final_long_df.copy()

# %%
mask = final_long_df["secondary_keyword"].astype(str).str.strip().eq("None")

print("Rows with secondary_keyword == 'None':", mask.sum())

# Remove them
final_long_df = final_long_df[~mask].reset_index(drop=True)

print("Final row count:", len(final_long_df))
# Out:
# Rows with secondary_keyword == 'None': 4
# Final row count: 1719

# %% [markdown]
# GET RANK FROM SERPER

# %%
import requests
import pandas as pd

# config
SERPER_API_KEY = "6769b8e78f7e96c5ff1793582bebbe532085d6be"   # replace with your real key
API_URL = "https://google.serper.dev/search"

headers = {
    "X-API-KEY": SERPER_API_KEY,
    "Content-Type": "application/json"
}

# %%
# run over all keywords
# df_keywords = dict_raw_df.copy()

# run over all the keywords for the core blogs
final_long_df = final_long_df[["primary_keyword", "secondary_keyword", "hero_url"]].drop_duplicates()
print(f"Secondary keywords (core pages) selected for ranking: {len(final_long_df)}")
# Out:
# Secondary keywords (core pages) selected for ranking: 1719

# %%
# ------------------------------------------------------------
#  RANK EXTRACTION SECTION
# ------------------------------------------------------------

results = []

for idx, row in final_long_df.iterrows():
    keyword = row["secondary_keyword"].strip()
    hero_url = row["hero_url"].strip()

    payload = {
        "q": keyword,
        "gl": "us",
        "hl": "en",
        "num": 100
    }

    try:
        res = requests.post(API_URL, headers=headers, json=payload, timeout=20)
        print(f"{idx}: status {res.status_code}")

        res.raise_for_status()
        data = res.json()

        # Find hero_url in organic results
        rank = None
        for i, r in enumerate(data.get("organic", []), start=1):
            if hero_url in r.get("link", ""):
                rank = i
                break

        rank_value = rank if rank is not None else "100+"

    except Exception as e:
        print(f"Error for {keyword}: {e}")
        rank_value = "100+"

    results.append({
        "primary_keyword": row["primary_keyword"],
        "secondary_keyword": keyword,
        "hero_url": hero_url,
        "rank": rank_value
    })

rank_df = pd.DataFrame(results)
print("\nExtracted ranks:")
print(rank_df.head())
# Out:
# 0: status 200
# 1: status 200
# 2: status 200
# 3: status 200
# 4: status 200
# 5: status 200
# 6: status 200
# 7: status 200
# 8: status 200
# 9: status 200
# 10: status 200
# 11: status 200
# 12: status 200
# 13: status 200
# 14: status 200
# 15: status 200
# 16: status 200
# 17: status 200
# 18: status 200
# 19: status 200
# 20: status 200
# 21: status 200
# 22: status 200
# 23: status 200
# 24: status 200
# 25: status 200
# 26: status 200
# 27: status 200
# 28: status 200
# 29: status 200
# 30: status 200
# 31: status 200
# 32: status 200
# 33: status 200
# 34: status 200
# 35: status 200
# 36: status 200
# 37: status 200
# 38: status 200
# 39: status 200
# 40: status 200
# 41: status 200
# 42: status 200
# 43: status 200
# 44: status 200
# 45: status 200
# 46: status 200
# 47: status 200
# 48: status 200
# 49: status 200
# 50: status 200
# 51: status 200
# 52: status 200
# 53: status 200
# 54: status 200
# 55: status 200
# 56: status 200
# 57: status 200
# 58: status 200
# 59: status 200
# 60: status 200
# 61: status 200
# 62: status 200
# 63: status 200
# 64: status 200
# 65: status 200
# 66: status 200
# 67: status 200
# 68: status 200
# 69: status 200
# 70: status 200
# 71: status 200
# 72: status 200
# 73: status 200
# 74: status 200
# 75: status 200
# 76: status 200
# 77: status 200
# 78: status 200
# 79: status 200
# 80: status 200
# 81: status 200
# 82: status 200
# 83: status 200
# 84: status 200
# 85: status 200
# 86: status 200
# 87: status 200
# 88: status 200
# 89: status 200
# 90: status 200
# 91: status 200
# 92: status 200
# 93: status 200
# 94: status 200
# 95: status 200
# 96: status 200
# 97: status 200
# 98: status 200
# 99: status 200
# 100: status 200
# 101: status 200
# 102: status 200
# 103: status 200
# 104: status 200
# 105: status 200
# 106: status 200
# 107: status 200
# 108: status 200
# 109: status 200
# 110: status 200
# 111: status 200
# 112: status 200
# 113: status 200
# 114: status 200
# 115: status 200
# 116: status 200
# 117: status 200
# 118: status 200
# 119: status 200
# 120: status 200
# 121: status 200
# 122: status 200
# 123: status 200
# 124: status 200
# 125: status 200
# 126: status 200
# 127: status 200
# 128: status 200
# 129: status 200
# 130: status 200
# 131: status 200
# 132: status 200
# 133: status 200
# 134: status 200
# 135: status 200
# 136: status 200
# 137: status 200
# 138: status 200
# 139: status 200
# 140: status 200
# 141: status 200
# 142: status 200
# 143: status 200
# 144: status 200
# 145: status 200
# 146: status 200
# 147: status 200
# 148: status 200
# 149: status 200
# 150: status 200
# 151: status 200
# 152: status 200
# 153: status 200
# 154: status 200
# 155: status 200
# 156: status 200
# 157: status 200
# 158: status 200
# 159: status 200
# 160: status 200
# 161: status 200
# 162: status 200
# 163: status 200
# 164: status 200
# 165: status 200
# 166: status 200
# 167: status 200
# 168: status 200
# 169: status 200
# 170: status 200
# 171: status 200
# 172: status 200
# 173: status 200
# 174: status 200
# 175: status 200
# 176: status 200
# 177: status 200
# 178: status 200
# 179: status 200
# 180: status 200
# 181: status 200
# 182: status 200
# 183: status 200
# 184: status 200
# 185: status 200
# 186: status 200
# 187: status 200
# 188: status 200
# 189: status 200
# 190: status 200
# 191: status 200
# 192: status 200
# 193: status 200
# 194: status 200
# 195: status 200
# 196: status 200
# 197: status 200
# 198: status 200
# 199: status 200
# 200: status 200
# 201: status 200
# 202: status 200
# 203: status 200
# 204: status 200
# 205: status 200
# 206: status 200
# 207: status 200
# 208: status 200
# 209: status 200
# 210: status 200
# 211: status 200
# 212: status 200
# 213: status 200
# 214: status 200
# 215: status 200
# 216: status 200
# 217: status 200
# 218: status 200
# 219: status 200
# 220: status 200
# 221: status 200
# 222: status 200
# 223: status 200
# 224: status 200
# 225: status 200
# 226: status 200
# 227: status 200
# 228: status 200
# 229: status 200
# 230: status 200
# 231: status 200
# 232: status 200
# 233: status 200
# 234: status 200
# 235: status 200
# 236: status 200
# 237: status 200
# 238: status 200
# 239: status 200
# 240: status 200
# 241: status 200
# 242: status 200
# 243: status 200
# 244: status 200
# 245: status 200
# 246: status 200
# 247: status 200
# 248: status 200
# 249: status 200
# 250: status 200
# 251: status 200
# 252: status 200
# 253: status 200
# 254: status 200
# 255: status 200
# 256: status 200
# 257: status 200
# 258: status 200
# 259: status 200
# 260: status 200
# 261: status 200
# 262: status 200
# 263: status 200
# 264: status 200
# 265: status 200
# 266: status 200
# 267: status 200
# 268: status 200
# 269: status 200
# 270: status 200
# 271: status 200
# 272: status 200
# 273: status 200
# 274: status 200
# 275: status 200
# 276: status 200
# 277: status 200
# 278: status 200
# 279: status 200
# 280: status 200
# 281: status 200
# 282: status 200
# 283: status 200
# 284: status 200
# 285: status 200
# 286: status 200
# 287: status 200
# 288: status 200
# 289: status 200
# 290: status 200
# 291: status 200
# 292: status 200
# 293: status 200
# 294: status 200
# 295: status 200
# 296: status 200
# 297: status 200
# 298: status 200
# 299: status 200
# 300: status 200
# 301: status 200
# 302: status 200
# 303: status 200
# 304: status 200
# 305: status 200
# 306: status 200
# 307: status 200
# 308: status 200
# 309: status 200
# 310: status 200
# 311: status 200
# 312: status 200
# 313: status 200
# 314: status 200
# 315: status 200
# 316: status 200
# 317: status 200
# 318: status 200
# 319: status 200
# 320: status 200
# 321: status 200
# 322: status 200
# 323: status 200
# 324: status 200
# 325: status 200
# 326: status 200
# 327: status 200
# 328: status 200
# 329: status 200
# 330: status 200
# 331: status 200
# 332: status 200
# 333: status 200
# 334: status 200
# 335: status 200
# 336: status 200
# 337: status 200
# 338: status 200
# 339: status 200
# 340: status 200
# 341: status 200
# 342: status 200
# 343: status 200
# 344: status 200
# 345: status 200
# 346: status 200
# 347: status 200
# 348: status 200
# 349: status 200
# 350: status 200
# 351: status 200
# 352: status 200
# 353: status 200
# 354: status 200
# 355: status 200
# 356: status 200
# 357: status 200
# 358: status 200
# 359: status 200
# 360: status 200
# 361: status 200
# 362: status 200
# 363: status 200
# 364: status 200
# 365: status 200
# 366: status 200
# 367: status 200
# 368: status 200
# 369: status 200
# 370: status 200
# 371: status 200
# 372: status 200
# 373: status 200
# 374: status 200
# 375: status 200
# 376: status 200
# 377: status 200
# 378: status 200
# 379: status 200
# 380: status 200
# 381: status 200
# 382: status 200
# 383: status 200
# 384: status 200
# 385: status 200
# 386: status 200
# 387: status 200
# 388: status 200
# 389: status 200
# 390: status 200
# 391: status 200
# 392: status 200
# 393: status 200
# 394: status 200
# 395: status 200
# 396: status 200
# 397: status 200
# 398: status 200
# 399: status 200
# 400: status 200
# 401: status 200
# 402: status 200
# 403: status 200
# 404: status 200
# 405: status 200
# 406: status 200
# 407: status 200
# 408: status 200
# 409: status 200
# 410: status 200
# 411: status 200
# 412: status 200
# 413: status 200
# 414: status 200
# 415: status 200
# 416: status 200
# 417: status 200
# 418: status 200
# 419: status 200
# 420: status 200
# 421: status 200
# 422: status 200
# 423: status 200
# 424: status 200
# 425: status 200
# 426: status 200
# 427: status 200
# 428: status 200
# 429: status 200
# 430: status 200
# 431: status 200
# 432: status 200
# 433: status 200
# 434: status 200
# 435: status 200
# 436: status 200
# 437: status 200
# 438: status 200
# 439: status 200
# 440: status 200
# 441: status 200
# 442: status 200
# 443: status 200
# 444: status 200
# 445: status 200
# 446: status 200
# 447: status 200
# 448: status 200
# 449: status 200
# 450: status 200
# 451: status 200
# 452: status 200
# 453: status 200
# 454: status 200
# 455: status 200
# 456: status 200
# 457: status 200
# 458: status 200
# 459: status 200
# 460: status 200
# 461: status 200
# 462: status 200
# 463: status 200
# 464: status 200
# 465: status 200
# 466: status 200
# 467: status 200
# 468: status 200
# 469: status 200
# 470: status 200
# 471: status 200
# 472: status 200
# 473: status 200
# 474: status 200
# 475: status 200
# 476: status 200
# 477: status 200
# 478: status 200
# 479: status 200
# 480: status 200
# 481: status 200
# 482: status 200
# 483: status 200
# 484: status 200
# 485: status 200
# 486: status 200
# 487: status 200
# 488: status 200
# 489: status 200
# 490: status 200
# 491: status 200
# 492: status 200
# 493: status 200
# 494: status 200
# 495: status 200
# 496: status 200
# 497: status 200
# 498: status 200
# 499: status 200
# 500: status 200
# 501: status 200
# 502: status 200
# 503: status 200
# 504: status 200
# 505: status 200
# 506: status 200
# 507: status 200
# 508: status 200
# 509: status 200
# 510: status 200
# 511: status 200
# 512: status 200
# 513: status 200
# 514: status 200
# 515: status 200
# 516: status 200
# 517: status 200
# 518: status 200
# 519: status 200
# 520: status 200
# 521: status 200
# 522: status 200
# 523: status 200
# 524: status 200
# 525: status 200
# 526: status 200
# 527: status 200
# 528: status 200
# 529: status 200
# 530: status 200
# 531: status 200
# 532: status 200
# 533: status 200
# 534: status 200
# 535: status 200
# 536: status 200
# 537: status 200
# 538: status 200
# 539: status 200
# 540: status 200
# 541: status 200
# 542: status 200
# 543: status 200
# 544: status 200
# 545: status 200
# 546: status 200
# 547: status 200
# 548: status 200
# 549: status 200
# 550: status 200
# 551: status 200
# 552: status 200
# 553: status 200
# 554: status 200
# 555: status 200
# 556: status 200
# 557: status 200
# 558: status 200
# 559: status 200
# 560: status 200
# 561: status 200
# 562: status 200
# 563: status 200
# 564: status 200
# 565: status 200
# 566: status 200
# 567: status 200
# 568: status 200
# 569: status 200
# 570: status 200
# 571: status 200
# 572: status 200
# 573: status 200
# 574: status 200
# 575: status 200
# 576: status 200
# 577: status 200
# 578: status 200
# 579: status 200
# 580: status 200
# 581: status 200
# 582: status 200
# 583: status 200
# 584: status 200
# 585: status 200
# 586: status 200
# 587: status 200
# 588: status 200
# 589: status 200
# 590: status 200
# 591: status 200
# 592: status 200
# 593: status 200
# 594: status 200
# 595: status 200
# 596: status 200
# 597: status 200
# 598: status 200
# 599: status 200
# 600: status 200
# 601: status 200
# 602: status 200
# 603: status 200
# 604: status 200
# 605: status 200
# 606: status 200
# 607: status 200
# 608: status 200
# 609: status 200
# 610: status 200
# 611: status 200
# 612: status 200
# 613: status 200
# 614: status 200
# 615: status 200
# 616: status 200
# 617: status 200
# 618: status 200
# 619: status 200
# 620: status 200
# 621: status 200
# 622: status 200
# 623: status 200
# 624: status 200
# 625: status 200
# 626: status 200
# 627: status 200
# 628: status 200
# 629: status 200
# 630: status 200
# 631: status 200
# 632: status 200
# 633: status 200
# 634: status 200
# 635: status 200
# 636: status 200
# 637: status 200
# 638: status 200
# 639: status 200
# 640: status 200
# 641: status 200
# 642: status 200
# 643: status 200
# 644: status 200
# 645: status 200
# 646: status 200
# 647: status 200
# 648: status 200
# 649: status 200
# 650: status 200
# 651: status 200
# 652: status 200
# 653: status 200
# 654: status 200
# 655: status 200
# 656: status 200
# 657: status 200
# 658: status 200
# 659: status 200
# 660: status 200
# 661: status 200
# 662: status 200
# 663: status 200
# 664: status 200
# 665: status 200
# 666: status 200
# 667: status 200
# 668: status 200
# 669: status 200
# 670: status 200
# 671: status 200
# 672: status 200
# 673: status 200
# 674: status 200
# 675: status 200
# 676: status 200
# 677: status 200
# 678: status 200
# 679: status 200
# 680: status 200
# 681: status 200
# 682: status 200
# 683: status 200
# 684: status 200
# 685: status 200
# 686: status 200
# 687: status 200
# 688: status 200
# 689: status 200
# 690: status 200
# 691: status 200
# 692: status 200
# 693: status 200
# 694: status 200
# 695: status 200
# 696: status 200
# 697: status 200
# 698: status 200
# 699: status 200
# 700: status 200
# 701: status 200
# 702: status 200
# 703: status 200
# 704: status 200
# 705: status 200
# 706: status 200
# 707: status 200
# 708: status 200
# 709: status 200
# 710: status 200
# 711: status 200
# 712: status 200
# 713: status 200
# 714: status 200
# 715: status 200
# 716: status 200
# 717: status 200
# 718: status 200
# 719: status 200
# 720: status 200
# 721: status 200
# 722: status 200
# 723: status 200
# 724: status 200
# 725: status 200
# 726: status 200
# 727: status 200
# 728: status 200
# 729: status 200
# 730: status 200
# 731: status 200
# 732: status 200
# 733: status 200
# 734: status 200
# 735: status 200
# 736: status 200
# 737: status 200
# 738: status 200
# 739: status 200
# 740: status 200
# 741: status 200
# 742: status 200
# 743: status 200
# 744: status 200
# 745: status 200
# 746: status 200
# 747: status 200
# 748: status 200
# 749: status 200
# 750: status 200
# 751: status 200
# 752: status 200
# 753: status 200
# 754: status 200
# 755: status 200
# 756: status 200
# 757: status 200
# 758: status 200
# 759: status 200
# 760: status 200
# 761: status 200
# 762: status 200
# 763: status 200
# 764: status 200
# 765: status 200
# 766: status 200
# 767: status 200
# 768: status 200
# 769: status 200
# 770: status 200
# 771: status 200
# 772: status 200
# 773: status 200
# 774: status 200
# 775: status 200
# 776: status 200
# 777: status 200
# 778: status 200
# 779: status 200
# 780: status 200
# 781: status 200
# 782: status 200
# 783: status 200
# 784: status 200
# 785: status 200
# 786: status 200
# 787: status 200
# 788: status 200
# 789: status 200
# 790: status 200
# 791: status 200
# 792: status 200
# 793: status 200
# 794: status 200
# 795: status 200
# 796: status 200
# 797: status 200
# 798: status 200
# 799: status 200
# 800: status 200
# 801: status 200
# 802: status 200
# 803: status 200
# 804: status 200
# 805: status 200
# 806: status 200
# 807: status 200
# 808: status 200
# 809: status 200
# 810: status 200
# 811: status 200
# 812: status 200
# 813: status 200
# 814: status 200
# 815: status 200
# 816: status 200
# 817: status 200
# 818: status 200
# 819: status 200
# 820: status 200
# 821: status 200
# 822: status 200
# 823: status 200
# 824: status 200
# 825: status 200
# 826: status 200
# 827: status 200
# 828: status 200
# 829: status 200
# 830: status 200
# 831: status 200
# 832: status 200
# 833: status 200
# 834: status 200
# 835: status 200
# 836: status 200
# 837: status 200
# 838: status 200
# 839: status 200
# 840: status 200
# 841: status 200
# 842: status 200
# 843: status 200
# 844: status 200
# 845: status 200
# 846: status 200
# 847: status 200
# 848: status 200
# 849: status 200
# 850: status 200
# 851: status 200
# 852: status 200
# 853: status 200
# 854: status 200
# 855: status 200
# 856: status 200
# 857: status 200
# 858: status 200
# 859: status 200
# 860: status 200
# 861: status 200
# 862: status 200
# 863: status 200
# 864: status 200
# 865: status 200
# 866: status 200
# 867: status 200
# 868: status 200
# 869: status 200
# 870: status 200
# 871: status 200
# 872: status 200
# 873: status 200
# 874: status 200
# 875: status 200
# 876: status 200
# 877: status 200
# 878: status 200
# 879: status 200
# 880: status 200
# 881: status 200
# 882: status 200
# 883: status 200
# 884: status 200
# 885: status 200
# 886: status 200
# 887: status 200
# 888: status 200
# 889: status 200
# 890: status 200
# 891: status 200
# 892: status 200
# 893: status 200
# 894: status 200
# 895: status 200
# 896: status 200
# 897: status 200
# 898: status 200
# 899: status 200
# 900: status 200
# 901: status 200
# 902: status 200
# 903: status 200
# 904: status 200
# 905: status 200
# 906: status 200
# 907: status 200
# 908: status 200
# 909: status 200
# 910: status 200
# 911: status 200
# 912: status 200
# 913: status 200
# 914: status 200
# 915: status 200
# 916: status 200
# 917: status 200
# 918: status 200
# 919: status 200
# 920: status 200
# 921: status 200
# 922: status 200
# 923: status 200
# 924: status 200
# 925: status 200
# 926: status 200
# 927: status 200
# 928: status 200
# 929: status 200
# 930: status 200
# 931: status 200
# 932: status 200
# 933: status 200
# 934: status 200
# 935: status 200
# 936: status 200
# 937: status 200
# 938: status 200
# 939: status 200
# 940: status 200
# 941: status 200
# 942: status 200
# 943: status 200
# 944: status 200
# 945: status 200
# 946: status 200
# 947: status 200
# 948: status 200
# 949: status 200
# 950: status 200
# 951: status 200
# 952: status 200
# 953: status 200
# 954: status 200
# 955: status 200
# 956: status 200
# 957: status 200
# 958: status 200
# 959: status 200
# 960: status 200
# 961: status 200
# 962: status 200
# 963: status 200
# 964: status 200
# 965: status 200
# 966: status 200
# 967: status 200
# 968: status 200
# 969: status 200
# 970: status 200
# 971: status 200
# 972: status 200
# 973: status 200
# 974: status 200
# 975: status 200
# 976: status 200
# 977: status 200
# 978: status 200
# 979: status 200
# 980: status 200
# 981: status 200
# 982: status 200
# 983: status 200
# 984: status 200
# 985: status 200
# 986: status 200
# 987: status 200
# 988: status 200
# 989: status 200
# 990: status 200
# 991: status 200
# 992: status 200
# 993: status 200
# 994: status 200
# 995: status 200
# 996: status 200
# 997: status 200
# 998: status 200
# 999: status 200
# 1000: status 200
# 1001: status 200
# 1002: status 200
# 1003: status 200
# 1004: status 200
# 1005: status 200
# 1006: status 200
# 1007: status 200
# 1008: status 200
# 1009: status 200
# 1010: status 200
# 1011: status 200
# 1012: status 200
# 1013: status 200
# 1014: status 200
# 1015: status 200
# 1016: status 200
# 1017: status 200
# 1018: status 200
# 1019: status 200
# 1020: status 200
# 1021: status 200
# 1022: status 200
# 1023: status 200
# 1024: status 200
# 1025: status 200
# 1026: status 200
# 1027: status 200
# 1028: status 200
# 1029: status 200
# 1030: status 200
# 1031: status 200
# 1032: status 200
# 1033: status 200
# 1034: status 200
# 1035: status 200
# 1036: status 200
# 1037: status 200
# 1038: status 200
# 1039: status 200
# 1040: status 200
# 1041: status 200
# 1042: status 200
# 1043: status 200
# 1044: status 200
# 1045: status 200
# 1046: status 200
# 1047: status 200
# 1048: status 200
# 1049: status 200
# 1050: status 200
# 1051: status 200
# 1052: status 200
# 1053: status 200
# 1054: status 200
# 1055: status 200
# 1056: status 200
# 1057: status 200
# 1058: status 200
# 1059: status 200
# 1060: status 200
# 1061: status 200
# 1062: status 200
# 1063: status 200
# 1064: status 200
# 1065: status 200
# 1066: status 200
# 1067: status 200
# 1068: status 200
# 1069: status 200
# 1070: status 200
# 1071: status 200
# 1072: status 200
# 1073: status 200
# 1074: status 200
# 1075: status 200
# 1076: status 200
# 1077: status 200
# 1078: status 200
# 1079: status 200
# 1080: status 200
# 1081: status 200
# 1082: status 200
# 1083: status 200
# 1084: status 200
# 1085: status 200
# 1086: status 200
# 1087: status 200
# 1088: status 200
# 1089: status 200
# 1090: status 200
# 1091: status 200
# 1092: status 200
# 1093: status 200
# 1094: status 200
# 1095: status 200
# 1096: status 200
# 1097: status 200
# 1098: status 200
# 1099: status 200
# 1100: status 200
# 1101: status 200
# 1102: status 200
# 1103: status 200
# 1104: status 200
# 1105: status 200
# 1106: status 200
# 1107: status 200
# 1108: status 200
# 1109: status 200
# 1110: status 200
# 1111: status 200
# 1112: status 200
# 1113: status 200
# 1114: status 200
# 1115: status 200
# 1116: status 200
# 1117: status 200
# 1118: status 200
# 1119: status 200
# 1120: status 200
# 1121: status 200
# 1122: status 200
# 1123: status 200
# 1124: status 200
# 1125: status 200
# 1126: status 200
# 1127: status 200
# 1128: status 200
# 1129: status 200
# 1130: status 200
# 1131: status 200
# 1132: status 200
# 1133: status 200
# 1134: status 200
# 1135: status 200
# 1136: status 200
# 1137: status 200
# 1138: status 200
# 1139: status 200
# 1140: status 200
# 1141: status 200
# 1142: status 200
# 1143: status 200
# 1144: status 200
# 1145: status 200
# 1146: status 200
# 1147: status 200
# 1148: status 200
# 1149: status 200
# 1150: status 200
# 1151: status 200
# 1152: status 200
# 1153: status 200
# 1154: status 200
# 1155: status 200
# 1156: status 200
# 1157: status 200
# 1158: status 200
# 1159: status 200
# 1160: status 200
# 1161: status 200
# 1162: status 200
# 1163: status 200
# 1164: status 200
# 1165: status 200
# 1166: status 200
# 1167: status 200
# 1168: status 200
# 1169: status 200
# 1170: status 200
# 1171: status 200
# 1172: status 200
# 1173: status 200
# 1174: status 200
# 1175: status 200
# 1176: status 200
# 1177: status 200
# 1178: status 200
# 1179: status 200
# 1180: status 200
# 1181: status 200
# 1182: status 200
# 1183: status 200
# 1184: status 200
# 1185: status 200
# 1186: status 200
# 1187: status 200
# 1188: status 200
# 1189: status 200
# 1190: status 200
# 1191: status 200
# 1192: status 200
# 1193: status 200
# 1194: status 200
# 1195: status 200
# 1196: status 200
# 1197: status 200
# 1198: status 200
# 1199: status 200
# 1200: status 200
# 1201: status 200
# 1202: status 200
# 1203: status 200
# 1204: status 200
# 1205: status 200
# 1206: status 200
# 1207: status 200
# 1208: status 200
# 1209: status 200
# 1210: status 200
# 1211: status 200
# 1212: status 200
# 1213: status 200
# 1214: status 200
# 1215: status 200
# 1216: status 200
# 1217: status 200
# 1218: status 200
# 1219: status 200
# 1220: status 200
# 1221: status 200
# 1222: status 200
# 1223: status 200
# 1224: status 200
# 1225: status 200
# 1226: status 200
# 1227: status 200
# 1228: status 200
# 1229: status 200
# 1230: status 200
# 1231: status 200
# 1232: status 200
# 1233: status 200
# 1234: status 200
# 1235: status 200
# 1236: status 200
# 1237: status 200
# 1238: status 200
# 1239: status 200
# 1240: status 200
# 1241: status 200
# 1242: status 200
# 1243: status 200
# 1244: status 200
# 1245: status 200
# 1246: status 200
# 1247: status 200
# 1248: status 200
# 1249: status 200
# 1250: status 200
# 1251: status 200
# 1252: status 200
# 1253: status 200
# 1254: status 200
# 1255: status 200
# 1256: status 200
# 1257: status 200
# 1258: status 200
# 1259: status 200
# 1260: status 200
# 1261: status 200
# 1262: status 200
# 1263: status 200
# 1264: status 200
# 1265: status 200
# 1266: status 200
# 1267: status 200
# 1268: status 200
# 1269: status 200
# 1270: status 200
# 1271: status 200
# 1272: status 200
# 1273: status 200
# 1274: status 200
# 1275: status 200
# 1276: status 200
# 1277: status 200
# 1278: status 200
# 1279: status 200
# 1280: status 200
# 1281: status 200
# 1282: status 200
# 1283: status 200
# 1284: status 200
# 1285: status 200
# 1286: status 200
# 1287: status 200
# 1288: status 200
# 1289: status 200
# 1290: status 200
# 1291: status 200
# 1292: status 200
# 1293: status 200
# 1294: status 200
# 1295: status 200
# 1296: status 200
# 1297: status 200
# 1298: status 200
# 1299: status 200
# 1300: status 200
# 1301: status 200
# 1302: status 200
# 1303: status 200
# 1304: status 200
# 1305: status 200
# 1306: status 200
# 1307: status 200
# 1308: status 200
# 1309: status 200
# 1310: status 200
# 1311: status 200
# 1312: status 200
# 1313: status 200
# 1314: status 200
# 1315: status 200
# 1316: status 200
# 1317: status 200
# 1318: status 200
# 1319: status 200
# 1320: status 200
# 1321: status 200
# 1322: status 200
# 1323: status 200
# 1324: status 200
# 1325: status 200
# 1326: status 200
# 1327: status 200
# 1328: status 200
# 1329: status 200
# 1330: status 200
# 1331: status 200
# 1332: status 200
# 1333: status 200
# 1334: status 200
# 1335: status 200
# 1336: status 200
# 1337: status 200
# 1338: status 200
# 1339: status 200
# 1340: status 200
# 1341: status 200
# 1342: status 200
# 1343: status 200
# 1344: status 200
# 1345: status 200
# 1346: status 200
# 1347: status 200
# 1348: status 200
# 1349: status 200
# 1350: status 200
# 1351: status 200
# 1352: status 200
# 1353: status 200
# 1354: status 200
# 1355: status 200
# 1356: status 200
# 1357: status 200
# 1358: status 200
# 1359: status 200
# 1360: status 200
# 1361: status 200
# 1362: status 200
# 1363: status 200
# 1364: status 200
# 1365: status 200
# 1366: status 200
# 1367: status 200
# 1368: status 200
# 1369: status 200
# 1370: status 200
# 1371: status 200
# 1372: status 200
# 1373: status 200
# 1374: status 200
# 1375: status 200
# 1376: status 200
# 1377: status 200
# 1378: status 200
# 1379: status 200
# 1380: status 200
# 1381: status 200
# 1382: status 200
# 1383: status 200
# 1384: status 200
# 1385: status 200
# 1386: status 200
# 1387: status 200
# 1388: status 200
# 1389: status 200
# 1390: status 200
# 1391: status 200
# 1392: status 200
# 1393: status 200
# 1394: status 200
# 1395: status 200
# 1396: status 200
# 1397: status 200
# 1398: status 200
# 1399: status 200
# 1400: status 200
# 1401: status 200
# 1402: status 200
# 1403: status 200
# 1404: status 200
# 1405: status 200
# 1406: status 200
# 1407: status 200
# 1408: status 200
# 1409: status 200
# 1410: status 200
# 1411: status 200
# 1412: status 200
# 1413: status 200
# 1414: status 200
# 1415: status 200
# 1416: status 200
# 1417: status 200
# 1418: status 200
# 1419: status 200
# 1420: status 200
# 1421: status 200
# 1422: status 200
# 1423: status 200
# 1424: status 200
# 1425: status 200
# 1426: status 200
# 1427: status 200
# 1428: status 200
# 1429: status 200
# 1430: status 200
# 1431: status 200
# 1432: status 200
# 1433: status 200
# 1434: status 200
# 1435: status 200
# 1436: status 200
# 1437: status 200
# 1438: status 200
# 1439: status 200
# 1440: status 200
# 1441: status 200
# 1442: status 200
# 1443: status 200
# 1444: status 200
# 1445: status 200
# 1446: status 200
# 1447: status 200
# 1448: status 200
# 1449: status 200
# 1450: status 200
# 1451: status 200
# 1452: status 200
# 1453: status 200
# 1454: status 200
# 1455: status 200
# 1456: status 200
# 1457: status 200
# 1458: status 200
# 1459: status 200
# 1460: status 200
# 1461: status 200
# 1462: status 200
# 1463: status 200
# 1464: status 200
# 1465: status 200
# 1466: status 200
# 1467: status 200
# 1468: status 200
# 1469: status 200
# 1470: status 200
# 1471: status 200
# 1472: status 200
# 1473: status 200
# 1474: status 200
# 1475: status 200
# 1476: status 200
# 1477: status 200
# 1478: status 200
# 1479: status 200
# 1480: status 200
# 1481: status 200
# 1482: status 200
# 1483: status 200
# 1484: status 200
# 1485: status 200
# 1486: status 200
# 1487: status 200
# 1488: status 200
# 1489: status 200
# 1490: status 200
# 1491: status 200
# 1492: status 200
# 1493: status 200
# 1494: status 200
# 1495: status 200
# 1496: status 200
# 1497: status 200
# 1498: status 200
# 1499: status 200
# 1500: status 200
# 1501: status 200
# 1502: status 200
# 1503: status 200
# 1504: status 200
# 1505: status 200
# 1506: status 200
# 1507: status 200
# 1508: status 200
# 1509: status 200
# 1510: status 200
# 1511: status 200
# 1512: status 200
# 1513: status 200
# 1514: status 200
# 1515: status 200
# 1516: status 200
# 1517: status 200
# 1518: status 200
# 1519: status 200
# 1520: status 200
# 1521: status 200
# 1522: status 200
# 1523: status 200
# 1524: status 200
# 1525: status 200
# 1526: status 200
# 1527: status 200
# 1528: status 200
# 1529: status 200
# 1530: status 200
# 1531: status 200
# 1532: status 200
# 1533: status 200
# 1534: status 200
# 1535: status 200
# 1536: status 200
# 1537: status 200
# 1538: status 200
# 1539: status 200
# 1540: status 200
# 1541: status 200
# 1542: status 200
# 1543: status 200
# 1544: status 200
# 1545: status 200
# 1546: status 200
# 1547: status 200
# 1548: status 200
# 1549: status 200
# 1550: status 200
# 1551: status 200
# 1552: status 200
# 1553: status 200
# 1554: status 200
# 1555: status 200
# 1556: status 200
# 1557: status 200
# 1558: status 200
# 1559: status 200
# 1560: status 200
# 1561: status 200
# 1562: status 200
# 1563: status 200
# 1564: status 200
# 1565: status 200
# 1566: status 200
# 1567: status 200
# 1568: status 200
# 1569: status 200
# 1570: status 200
# 1571: status 200
# 1572: status 200
# 1573: status 200
# 1574: status 200
# 1575: status 200
# 1576: status 200
# 1577: status 200
# 1578: status 200
# 1579: status 200
# 1580: status 200
# 1581: status 200
# 1582: status 200
# 1583: status 200
# 1584: status 200
# 1585: status 200
# 1586: status 200
# 1587: status 200
# 1588: status 200
# 1589: status 200
# 1590: status 200
# 1591: status 200
# 1592: status 200
# 1593: status 200
# 1594: status 200
# 1595: status 200
# 1596: status 200
# 1597: status 200
# 1598: status 200
# 1599: status 200
# 1600: status 200
# 1601: status 200
# 1602: status 200
# 1603: status 200
# 1604: status 200
# 1605: status 200
# 1606: status 200
# 1607: status 200
# 1608: status 200
# 1609: status 200
# 1610: status 200
# 1611: status 200
# 1612: status 200
# 1613: status 200
# 1614: status 200
# 1615: status 200
# 1616: status 200
# 1617: status 200
# 1618: status 200
# 1619: status 200
# 1620: status 200
# 1621: status 200
# 1622: status 200
# 1623: status 200
# 1624: status 200
# 1625: status 200
# 1626: status 200
# 1627: status 200
# 1628: status 200
# 1629: status 200
# 1630: status 200
# 1631: status 200
# 1632: status 200
# 1633: status 200
# 1634: status 200
# 1635: status 200
# 1636: status 200
# 1637: status 200
# 1638: status 200
# 1639: status 200
# 1640: status 200
# 1641: status 200
# 1642: status 200
# 1643: status 200
# 1644: status 200
# 1645: status 200
# 1646: status 200
# 1647: status 200
# 1648: status 200
# 1649: status 200
# 1650: status 200
# 1651: status 200
# 1652: status 200
# 1653: status 200
# 1654: status 200
# 1655: status 200
# 1656: status 200
# 1657: status 200
# 1658: status 200
# 1659: status 200
# 1660: status 200
# 1661: status 200
# 1662: status 200
# 1663: status 200
# 1664: status 200
# 1665: status 200
# 1666: status 200
# 1667: status 200
# 1668: status 200
# 1669: status 200
# 1670: status 200
# 1671: status 200
# 1672: status 200
# 1673: status 200
# 1674: status 200
# 1675: status 200
# 1676: status 200
# 1677: status 200
# 1678: status 200
# 1679: status 200
# 1680: status 200
# 1681: status 200
# 1682: status 200
# 1683: status 200
# 1684: status 200
# 1685: status 200
# 1686: status 200
# 1687: status 200
# 1688: status 200
# 1689: status 200
# 1690: status 200
# 1691: status 200
# 1692: status 200
# 1693: status 200
# 1694: status 200
# 1695: status 200
# 1696: status 200
# 1697: status 200
# 1698: status 200
# 1699: status 200
# 1700: status 200
# 1701: status 200
# 1702: status 200
# 1703: status 200
# 1704: status 200
# 1705: status 200
# 1706: status 200
# 1707: status 200
# 1708: status 200
# 1709: status 200
# 1710: status 200
# 1711: status 200
# 1712: status 200
# 1713: status 200
# 1714: status 200
# 1715: status 200
# 1716: status 200
# 1717: status 200
# 1718: status 200
#
# Extracted ranks:
#             primary_keyword             secondary_keyword  \
# 0          seo for plumbers            plumber seo expert
# 1  manufacturing web design      manufacturing web design
# 2  manufacturing web design  manufacturing website design
# 3  manufacturing web design      web design manufacturing
# 4  manufacturing web design         manufacturing website
#
#                                             hero_url  rank
# 0      https://www.gushwork.ai/blog/seo-for-plumbers  100+
# 1  https://www.gushwork.ai/blog/best-manufacturin...  100+
# 2  https://www.gushwork.ai/blog/best-manufacturin...  100+
# 3  https://www.gushwork.ai/blog/best-manufacturin...  100+
# 4  https://www.gushwork.ai/blog/best-manufacturin...  100+

# %%
# rank_df[rank_df["rank"] != "100+"]
#rank_df = rank_df.drop(columns=["extracted_date"])
rank_df.head()
# Out:
#             primary_keyword             secondary_keyword  \
# 0          seo for plumbers            plumber seo expert
# 1  manufacturing web design      manufacturing web design
# 2  manufacturing web design  manufacturing website design
# 3  manufacturing web design      web design manufacturing
# 4  manufacturing web design         manufacturing website
#
#                                             hero_url  rank
# 0      https://www.gushwork.ai/blog/seo-for-plumbers  100+
# 1  https://www.gushwork.ai/blog/best-manufacturin...  100+
# 2  https://www.gushwork.ai/blog/best-manufacturin...  100+
# 3  https://www.gushwork.ai/blog/best-manufacturin...  100+
# 4  https://www.gushwork.ai/blog/best-manufacturin...  100+

# %%
from datetime import date
today = date.today()

rank_df = rank_df.copy()   # prevent SettingWithCopy issues

rank_df.loc[:, "extracted_date"] = today
rank_df["extracted_date"] = pd.to_datetime(rank_df["extracted_date"]).dt.date

rank_df = rank_df[
    ["primary_keyword", "secondary_keyword", "hero_url", "rank", "extracted_date"]
]

# %%
engine.dispose()
engine = create_engine(DB_URL, pool_pre_ping=True)

today = pd.Timestamp.utcnow().date()

with engine.begin() as conn:
    rows = conn.execute(text("""
        SELECT COUNT(*)
        FROM gist.gush_serper_rank_history
        WHERE extracted_date = :d
    """), {"d": today}).scalar()

print("Rows already present for", today, "=", rows)
# Out:
# Rows already present for 2025-12-23 = 0

# %%
with engine.begin() as conn:
    deleted = conn.execute(text("""
        DELETE FROM gist.gush_serper_rank_history
        WHERE extracted_date = :d
    """), {"d": today}).rowcount

print("Deleted:", deleted)
# Out:
# Deleted: 0

# %%
dupes_inside_df = (
    rank_df[["secondary_keyword", "hero_url", "extracted_date", "rank"]]
    .duplicated()
    .sum()
)
print("Duplicates inside rank_df:", dupes_inside_df)
# Out:
# Duplicates inside rank_df: 0

# %%
rank_df = rank_df.drop_duplicates(
    subset=["secondary_keyword", "hero_url", "extracted_date"]
).reset_index(drop=True)

print("Rows after de-dup:", len(rank_df))
# Out:
# Rows after de-dup: 1719

# %%
# Reset broken transaction state
engine.dispose()
engine = create_engine(DB_URL)

rank_df.to_sql(
    name="gush_serper_rank_history",
    con=engine,
    schema="gist",
    if_exists="append",
    index=False,
    method="multi"
)

print(f"Inserted {len(rank_df)} rows.")
# Out:
# Inserted 1719 rows.
