# %% [markdown]
# <a href="https://colab.research.google.com/github/ShikharV010/gist_daily_runs/blob/main/Stored_Proc_Load.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required packages
# !pip install psycopg2-binary pandas

import psycopg2
import pandas as pd
import time
from datetime import datetime

# ---------------------------------------------------------
# PostgreSQL connection parameters
# ---------------------------------------------------------
pg_params = {
    'host': 'gw-rds-prod.celzx4qnlkfp.us-east-1.rds.amazonaws.com',
    'database': 'gw_prod',
    'user': 'airbyte_user',
    'password': 'airbyte_user_password',
    'port': '5432'
}

# ---------------------------------------------------------
# Stored procedures to EXCLUDE from execution
# ---------------------------------------------------------
EXCLUDED_PROCEDURES = {
    'gist.update_gtm_master_allcampaigns'
}

# ---------------------------------------------------------
# Materialized views to EXCLUDE from refresh
# ---------------------------------------------------------
EXCLUDED_MATVIEWS = {
    'gist.matv_writerallocation_contractedapproved_materialized',
    'gist.matv_gist_pageperformance'
}

# ---------------------------------------------------------
# Create audit table if it does not exist
# ---------------------------------------------------------
def create_audit_table():
    """Create the audit table if it doesn't exist"""
    conn = None
    cur = None
    try:
        conn = psycopg2.connect(**pg_params)
        cur = conn.cursor()

        cur.execute('''
            CREATE TABLE IF NOT EXISTS gist.audit_automated_procsandviews (
                id SERIAL PRIMARY KEY,
                object_name VARCHAR(255),
                object_type VARCHAR(50),
                start_time TIMESTAMP,
                end_time TIMESTAMP,
                duration_seconds NUMERIC(10,2),
                status VARCHAR(50),
                error_message TEXT
            )
        ''')

        conn.commit()
        print("Audit table created or already exists.")

    except Exception as e:
        print(f"Error creating audit table: {e}")
    finally:
        if cur:
            cur.close()
        if conn:
            conn.close()

# ---------------------------------------------------------
# Fetch procedures and materialized views from metadata view
# ---------------------------------------------------------
def get_procedures_and_matviews():
    """Get all stored procedures and materialized views from the view"""
    conn = None
    cur = None
    try:
        conn = psycopg2.connect(**pg_params)
        cur = conn.cursor()

        query = """
            SELECT name, object_type
            FROM gist.gist_procsandviews
            ORDER BY object_type, name
        """
        cur.execute(query)
        results = cur.fetchall()

        procedures = []
        matviews = []

        for name, obj_type in results:
            if obj_type == 'PROCEDURE':
                procedures.append(name)
            elif obj_type == 'MATERIALIZED VIEW':
                matviews.append(name)

        return procedures, matviews

    except Exception as e:
        print(f"Error getting objects from view: {e}")
        return [], []
    finally:
        if cur:
            cur.close()
        if conn:
            conn.close()

# ---------------------------------------------------------
# Execute a stored procedure with audit logging
# ---------------------------------------------------------
def execute_procedure(proc_name):
    """Execute a stored procedure and log the results"""
    conn = None
    cur = None

    full_proc_name = proc_name if proc_name.startswith('gist.') else f"gist.{proc_name}"

    try:
        conn = psycopg2.connect(**pg_params)
        conn.autocommit = True
        cur = conn.cursor()

        start_time = datetime.now()
        print(f"Executing {full_proc_name}() at {start_time}")

        cur.execute(f"CALL {full_proc_name}()")

        end_time = datetime.now()
        duration = (end_time - start_time).total_seconds()

        cur.execute('''
            INSERT INTO gist.audit_automated_procsandviews
            (object_name, object_type, start_time, end_time, duration_seconds, status, error_message)
            VALUES (%s, %s, %s, %s, %s, %s, %s)
        ''', (full_proc_name, 'PROCEDURE', start_time, end_time, duration, 'SUCCESS', None))

        print(f"Completed {full_proc_name}() in {duration:.2f} seconds")

    except Exception as e:
        error_message = str(e)
        end_time = datetime.now()
        duration = (end_time - start_time).total_seconds() if 'start_time' in locals() else 0

        if conn and not conn.closed:
            error_cur = conn.cursor()
            error_cur.execute('''
                INSERT INTO gist.audit_automated_procsandviews
                (object_name, object_type, start_time, end_time, duration_seconds, status, error_message)
                VALUES (%s, %s, %s, %s, %s, %s, %s)
            ''', (full_proc_name, 'PROCEDURE',
                  start_time if 'start_time' in locals() else None,
                  end_time, duration, 'ERROR', error_message))
            error_cur.close()

        print(f"Error executing {full_proc_name}: {error_message}")

    finally:
        if cur:
            cur.close()
        if conn:
            conn.close()

# ---------------------------------------------------------
# Refresh a materialized view with audit logging
# ---------------------------------------------------------
def refresh_matview(matview_name):
    """Refresh a materialized view and log the results"""
    conn = None
    cur = None

    full_matview_name = matview_name if matview_name.startswith('gist.') else f"gist.{matview_name}"

    try:
        conn = psycopg2.connect(**pg_params)
        conn.autocommit = True
        cur = conn.cursor()

        start_time = datetime.now()
        print(f"Refreshing {full_matview_name} at {start_time}")

        cur.execute(f"REFRESH MATERIALIZED VIEW {full_matview_name}")

        end_time = datetime.now()
        duration = (end_time - start_time).total_seconds()

        cur.execute('''
            INSERT INTO gist.audit_automated_procsandviews
            (object_name, object_type, start_time, end_time, duration_seconds, status, error_message)
            VALUES (%s, %s, %s, %s, %s, %s, %s)
        ''', (full_matview_name, 'MATERIALIZED VIEW',
              start_time, end_time, duration, 'SUCCESS', None))

        print(f"Refreshed {full_matview_name} in {duration:.2f} seconds")

    except Exception as e:
        error_message = str(e)
        end_time = datetime.now()
        duration = (end_time - start_time).total_seconds() if 'start_time' in locals() else 0

        if conn and not conn.closed:
            error_cur = conn.cursor()
            error_cur.execute('''
                INSERT INTO gist.audit_automated_procsandviews
                (object_name, object_type, start_time, end_time, duration_seconds, status, error_message)
                VALUES (%s, %s, %s, %s, %s, %s, %s)
            ''', (full_matview_name, 'MATERIALIZED VIEW',
                  start_time if 'start_time' in locals() else None,
                  end_time, duration, 'ERROR', error_message))
            error_cur.close()

        print(f"Error refreshing {full_matview_name}: {error_message}")

    finally:
        if cur:
            cur.close()
        if conn:
            conn.close()

# ---------------------------------------------------------
# Main runner
# ---------------------------------------------------------
def run_all_objects():
    """Run all stored procedures and refresh materialized views (with exclusions)"""
    print(f"Starting execution at {datetime.now()}")

    create_audit_table()

    procedures, matviews = get_procedures_and_matviews()
    print(f"Found {len(procedures)} procedures and {len(matviews)} materialized views")

    # Execute procedures first (excluding specific ones)
    print("\n--- EXECUTING STORED PROCEDURES ---")
    for proc in procedures:
        full_name = proc if proc.startswith('gist.') else f"gist.{proc}"

        if full_name in EXCLUDED_PROCEDURES:
            print(f"Skipping procedure {full_name}()")
            continue

        execute_procedure(proc)
        time.sleep(10)

    # Refresh materialized views (excluding specific ones)
    print("\n--- REFRESHING MATERIALIZED VIEWS ---")
    for matview in matviews:
        full_name = matview if matview.startswith('gist.') else f"gist.{matview}"

        if full_name in EXCLUDED_MATVIEWS:
            print(f"Skipping refresh for {full_name}")
            continue

        refresh_matview(matview)
        time.sleep(5)

    print(f"Completed all executions at {datetime.now()}")

# ---------------------------------------------------------
# Execute script
# ---------------------------------------------------------
run_all_objects()
# Out:
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.11-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading psycopg2_binary-2.9.11-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 42.0 MB/s eta 0:00:00
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.11
# Starting execution at 2026-01-13 15:05:18.981901
# Audit table created or already exists.
# Found 18 procedures and 19 materialized views
#
# --- EXECUTING STORED PROCEDURES ---
# Executing gist.debug_test_business_health() at 2026-01-13 15:05:19.958360
# Completed gist.debug_test_business_health() in 0.11 seconds
# Executing gist.sync_airbyte_table_v2() at 2026-01-13 15:05:30.396869
# Error executing gist.sync_airbyte_table_v2: procedure gist.sync_airbyte_table_v2() does not exist
# LINE 1: CALL gist.sync_airbyte_table_v2()
#              ^
# HINT:  No procedure matches the given name and argument types. You might need to add explicit type casts.
#
# Executing gist.sync_linkedinrec_ae_full() at 2026-01-13 15:05:40.754989
# Completed gist.sync_linkedinrec_ae_full() in 0.06 seconds
# Executing gist.update_20cvsz_hot_leads() at 2026-01-13 15:05:51.139072
# Completed gist.update_20cvsz_hot_leads() in 0.21 seconds
# Executing gist.update_accounts_csm() at 2026-01-13 15:06:01.668109
# Completed gist.update_accounts_csm() in 0.07 seconds
# Executing gist.update_accounts_master() at 2026-01-13 15:06:12.067585
# Error executing gist.update_accounts_master: column a.Sr_No does not exist
# LINE 18:             WHERE a."Sr_No" = g."Sr_No" AND a."campaign_id" ...
#                            ^
# HINT:  Perhaps you meant to reference the column "g.Sr_No".
# QUERY:  INSERT INTO temp_records (
#             record_type,
#             "CSM", "url", "Sr_No", "org_id", "status", "comment", "cust_id",
#             "End_Date", "Invoice_ID", "Start_Date", "blogs_count", "campaign_id",
#             "billing_org_id", "customer_email", "Local_Marketing", "backlinks_count",
#             "customer_entity_name", "type_of_subscription"
#         )
#         SELECT
#             'DELETE',
#             g."CSM", g."url", g."Sr_No", g."org_id", g."status", g."comment", g."cust_id",
#             g."End_Date", g."Invoice_ID", g."Start_Date", g."blogs_count", g."campaign_id",
#             g."billing_org_id", g."customer_email", g."Local_Marketing", g."backlinks_count",
#             g."customer_entity_name", g."type_of_subscription"
#         FROM gist.gist_accountsmaster g
#         WHERE NOT EXISTS (
#             SELECT 1
#             FROM airbyte_ingestion."MasterOrgSheet" a
#             WHERE a."Sr_No" = g."Sr_No" AND a."campaign_id" = g."campaign_id"
#         )
# CONTEXT:  PL/pgSQL function gist.update_accounts_master() line 124 at SQL statement
#
# Executing gist.update_active_writers() at 2026-01-13 15:06:22.425536
# Completed gist.update_active_writers() in 0.07 seconds
# Executing gist.update_bigrahwriterallocation() at 2026-01-13 15:06:32.829967
# Completed gist.update_bigrahwriterallocation() in 0.06 seconds
# Executing gist.update_business_health_long_format() at 2026-01-13 15:06:43.196418
# Error executing gist.update_business_health_long_format: invalid input syntax for type numeric: "11.5%"
# CONTEXT:  SQL statement "
#         INSERT INTO gist.business_health_long_format (
#             metric,
#             metric_month,
#             metric_type,
#             metric_value,
#             airbyte_extracted_at
#         )
#         SELECT
#             metrics,
#             TO_DATE(
#                 regexp_replace('apr_2025_actual', '_actual|_forecast', ''),
#                 'mon_YYYY'
#             ),
#             CASE
#                 WHEN 'apr_2025_actual' LIKE '%_actual' THEN 'actual'
#                 WHEN 'apr_2025_actual' LIKE '%_forecast' THEN 'forecast'
#             END,
#             NULLIF(apr_2025_actual, '')::numeric,
#             _airbyte_extracted_at
#         FROM tmp_business_health
#         WHERE NULLIF(apr_2025_actual, '') IS NOT NULL
#         ON CONFLICT DO NOTHING;
#
#         INSERT INTO gist.business_health_long_format (
#             metric,
#             metric_month,
#             metric_type,
#             metric_value,
#             airbyte_extracted_at
#         )
#         SELECT
#             metrics,
#             TO_DATE(
#                 regexp_replace('aug_2025_actual', '_actual|_forecast', ''),
#                 'mon_YYYY'
#             ),
#             CASE
#                 WHEN 'aug_2025_actual' LIKE '%_actual' THEN 'actual'
#                 WHEN 'aug_2025_actual' LIKE '%_forecast' THEN 'forecast'
#             END,
#             NULLIF(aug_2025_actual, '')::numeric,
#             _airbyte_extracted_at
#         FROM tmp_business_health
#         WHERE NULLIF(aug_2025_actual, '') IS NOT NULL
#         ON CONFLICT DO NOTHING;
#
#         INSERT INTO gist.business_health_long_format (
#             metric,
#             metric_month,
#             metric_type,
#             metric_value,
#             airbyte_extracted_at
#         )
#         SELECT
#             metrics,
#             TO_DATE(
#                 regexp_replace('dec_2024_actual', '_actual|_forecast', ''),
#                 'mon_YYYY'
#             ),
#             CASE
#                 WHEN 'dec_2024_actual' LIKE '%_actual' THEN 'actual'
#                 WHEN 'dec_2024_actual' LIKE '%_forecast' THEN 'forecast'
#             END,
#             NULLIF(dec_2024_actual, '')::numeric,
#             _airbyte_extracted_at
#         FROM tmp_business_health
#         WHERE NULLIF(dec_2024_actual, '') IS NOT NULL
#         ON CONFLICT DO NOTHING;
#
#         INSERT INTO gist.business_health_long_format (
#             metric,
#             metric_month,
#             metric_type,
#             metric_value,
#             airbyte_extracted_at
#         )
#         SELECT
#             metrics,
#             TO_DATE(
#                 regexp_replace('dec_2025_actual', '_actual|_forecast', ''),
#                 'mon_YYYY'
#             ),
#             CASE
#                 WHEN 'dec_2025_actual' LIKE '%_actual' THEN 'actual'
#                 WHEN 'dec_2025_actual' LIKE '%_forecast' THEN 'forecast'
#             END,
#             NULLIF(dec_2025_actual, '')::numeric,
#             _airbyte_extracted_at
#         FROM tmp_business_health
#         WHERE NULLIF(dec_2025_actual, '') IS NOT NULL
#         ON CONFLICT DO NOTHING;
#
#         INSERT INTO gist.business_health_long_format (
#             metric,
#             metric_month,
#             metric_type,
#             metric_value,
#             airbyte_extracted_at
#         )
#         SELECT
#             metrics,
#             TO_DATE(
#                 regexp_replace('feb_2025_actual', '_actual|_forecast', ''),
#                 'mon_YYYY'
#             ),
#             CASE
#                 WHEN 'feb_2025_actual' LIKE '%_actual' THEN 'actual'
#                 WHEN 'feb_2025_actual' LIKE '%_forecast' THEN 'forecast'
#             END,
#             NULLIF(feb_2025_actual, '')::numeric,
#             _airbyte_extracted_at
#         FROM tmp_business_health
#         WHERE NULLIF(feb_2025_actual, '') IS NOT NULL
#         ON CONFLICT DO NOTHING;
#
#         INSERT INTO gist.business_health_long_format (
#             metric,
#             metric_month,
#             metric_type,
#             metric_value,
#             airbyte_extracted_at
#         )
#         SELECT
#             metrics,
#             TO_DATE(
#                 regexp_replace('jan_2025_actual', '_actual|_forecast', ''),
#                 'mon_YYYY'
#             ),
#             CASE
#                 WHEN 'jan_2025_actual' LIKE '%_actual' THEN 'actual'
#                 WHEN 'jan_2025_actual' LIKE '%_forecast' THEN 'forecast'
#             END,
#             NULLIF(jan_2025_actual, '')::numeric,
#             _airbyte_extracted_at
#         FROM tmp_business_health
#         WHERE NULLIF(jan_2025_actual, '') IS NOT NULL
#         ON CONFLICT DO NOTHING;
#
#         INSERT INTO gist.business_health_long_format (
#             metric,
#             metric_month,
#             metric_type,
#             metric_value,
#             airbyte_extracted_at
#         )
#         SELECT
#             metrics,
#             TO_DATE(
#                 regexp_replace('jul_2025_actual', '_actual|_forecast', ''),
#                 'mon_YYYY'
#             ),
#             CASE
#                 WHEN 'jul_2025_actual' LIKE '%_actual' THEN 'actual'
#                 WHEN 'jul_2025_actual' LIKE '%_forecast' THEN 'forecast'
#             END,
#             NULLIF(jul_2025_actual, '')::numeric,
#             _airbyte_extracted_at
#         FROM tmp_business_health
#         WHERE NULLIF(jul_2025_actual, '') IS NOT NULL
#         ON CONFLICT DO NOTHING;
#
#         INSERT INTO gist.business_health_long_format (
#             metric,
#             metric_month,
#             metric_type,
#             metric_value,
#             airbyte_extracted_at
#         )
#         SELECT
#             metrics,
#             TO_DATE(
#                 regexp_replace('jun_2025_actual', '_actual|_forecast', ''),
#                 'mon_YYYY'
#             ),
#             CASE
#                 WHEN 'jun_2025_actual' LIKE '%_actual' THEN 'actual'
#                 WHEN 'jun_2025_actual' LIKE '%_forecast' THEN 'forecast'
#             END,
#             NULLIF(jun_2025_actual, '')::numeric,
#             _airbyte_extracted_at
#         FROM tmp_business_health
#         WHERE NULLIF(jun_2025_actual, '') IS NOT NULL
#         ON CONFLICT DO NOTHING;
#
#         INSERT INTO gist.business_health_long_format (
#             metric,
#             metric_month,
#             metric_type,
#             metric_value,
#             airbyte_extracted_at
#         )
#         SELECT
#             metrics,
#             TO_DATE(
#                 regexp_replace('mar_2025_actual', '_actual|_forecast', ''),
#                 'mon_YYYY'
#             ),
#             CASE
#                 WHEN 'mar_2025_actual' LIKE '%_actual' THEN 'actual'
#                 WHEN 'mar_2025_actual' LIKE '%_forecast' THEN 'forecast'
#             END,
#             NULLIF(mar_2025_actual, '')::numeric,
#             _airbyte_extracted_at
#         FROM tmp_business_health
#         WHERE NULLIF(mar_2025_actual, '') IS NOT NULL
#         ON CONFLICT DO NOTHING;
#
#         INSERT INTO gist.business_health_long_format (
#             metric,
#             metric_month,
#             metric_type,
#             metric_value,
#             airbyte_extracted_at
#         )
#         SELECT
#             metrics,
#             TO_DATE(
#                 regexp_replace('may_2025_actual', '_actual|_forecast', ''),
#                 'mon_YYYY'
#             ),
#             CASE
#                 WHEN 'may_2025_actual' LIKE '%_actual' THEN 'actual'
#                 WHEN 'may_2025_actual' LIKE '%_forecast' THEN 'forecast'
#             END,
#             NULLIF(may_2025_actual, '')::numeric,
#             _airbyte_extracted_at
#         FROM tmp_business_health
#         WHERE NULLIF(may_2025_actual, '') IS NOT NULL
#         ON CONFLICT DO NOTHING;
#
#         INSERT INTO gist.business_health_long_format (
#             metric,
#             metric_month,
#             metric_type,
#             metric_value,
#             airbyte_extracted_at
#         )
#         SELECT
#             metrics,
#             TO_DATE(
#                 regexp_replace('nov_2024_actual', '_actual|_forecast', ''),
#                 'mon_YYYY'
#             ),
#             CASE
#                 WHEN 'nov_2024_actual' LIKE '%_actual' THEN 'actual'
#                 WHEN 'nov_2024_actual' LIKE '%_forecast' THEN 'forecast'
#             END,
#             NULLIF(nov_2024_actual, '')::numeric,
#             _airbyte_extracted_at
#         FROM tmp_business_health
#         WHERE NULLIF(nov_2024_actual, '') IS NOT NULL
#         ON CONFLICT DO NOTHING;
#
#         INSERT INTO gist.business_health_long_format (
#             metric,
#             metric_month,
#             metric_type,
#             metric_value,
#             airbyte_extracted_at
#         )
#         SELECT
#             metrics,
#             TO_DATE(
#                 regexp_replace('nov_2025_actual', '_actual|_forecast', ''),
#                 'mon_YYYY'
#             ),
#             CASE
#                 WHEN 'nov_2025_actual' LIKE '%_actual' THEN 'actual'
#                 WHEN 'nov_2025_actual' LIKE '%_forecast' THEN 'forecast'
#             END,
#             NULLIF(nov_2025_actual, '')::numeric,
#             _airbyte_extracted_at
#         FROM tmp_business_health
#         WHERE NULLIF(nov_2025_actual, '') IS NOT NULL
#         ON CONFLICT DO NOTHING;
#
#         INSERT INTO gist.business_health_long_format (
#             metric,
#             metric_month,
#             metric_type,
#             metric_value,
#             airbyte_extracted_at
#         )
#         SELECT
#             metrics,
#             TO_DATE(
#                 regexp_replace('oct_2024_actual', '_actual|_forecast', ''),
#                 'mon_YYYY'
#             ),
#             CASE
#                 WHEN 'oct_2024_actual' LIKE '%_actual' THEN 'actual'
#                 WHEN 'oct_2024_actual' LIKE '%_forecast' THEN 'forecast'
#             END,
#             NULLIF(oct_2024_actual, '')::numeric,
#             _airbyte_extracted_at
#         FROM tmp_business_health
#         WHERE NULLIF(oct_2024_actual, '') IS NOT NULL
#         ON CONFLICT DO NOTHING;
#
#         INSERT INTO gist.business_health_long_format (
#             metric,
#             metric_month,
#             metric_type,
#             metric_value,
#             airbyte_extracted_at
#         )
#         SELECT
#             metrics,
#             TO_DATE(
#                 regexp_replace('oct_2025_actual', '_actual|_forecast', ''),
#                 'mon_YYYY'
#             ),
#             CASE
#                 WHEN 'oct_2025_actual' LIKE '%_actual' THEN 'actual'
#                 WHEN 'oct_2025_actual' LIKE '%_forecast' THEN 'forecast'
#             END,
#             NULLIF(oct_2025_actual, '')::numeric,
#             _airbyte_extracted_at
#         FROM tmp_business_health
#         WHERE NULLIF(oct_2025_actual, '') IS NOT NULL
#         ON CONFLICT DO NOTHING;
#
#         INSERT INTO gist.business_health_long_format (
#             metric,
#             metric_month,
#             metric_type,
#             metric_value,
#             airbyte_extracted_at
#         )
#         SELECT
#             metrics,
#             TO_DATE(
#                 regexp_replace('sep_2025_actual', '_actual|_forecast', ''),
#                 'mon_YYYY'
#             ),
#             CASE
#                 WHEN 'sep_2025_actual' LIKE '%_actual' THEN 'actual'
#                 WHEN 'sep_2025_actual' LIKE '%_forecast' THEN 'forecast'
#             END,
#             NULLIF(sep_2025_actual, '')::numeric,
#             _airbyte_extracted_at
#         FROM tmp_business_health
#         WHERE NULLIF(sep_2025_actual, '') IS NOT NULL
#         ON CONFLICT DO NOTHING;
#
#         INSERT INTO gist.business_health_long_format (
#             metric,
#             metric_month,
#             metric_type,
#             metric_value,
#             airbyte_extracted_at
#         )
#         SELECT
#             metrics,
#             TO_DATE(
#                 regexp_replace('dec_2025_forecast', '_actual|_forecast', ''),
#                 'mon_YYYY'
#             ),
#             CASE
#                 WHEN 'dec_2025_forecast' LIKE '%_actual' THEN 'actual'
#                 WHEN 'dec_2025_forecast' LIKE '%_forecast' THEN 'forecast'
#             END,
#             NULLIF(dec_2025_forecast, '')::numeric,
#             _airbyte_extracted_at
#         FROM tmp_business_health
#         WHERE NULLIF(dec_2025_forecast, '') IS NOT NULL
#         ON CONFLICT DO NOTHING;
#
#         INSERT INTO gist.business_health_long_format (
#             metric,
#             metric_month,
#             metric_type,
#             metric_value,
#             airbyte_extracted_at
#         )
#         SELECT
#             metrics,
#             TO_DATE(
#                 regexp_replace('feb_2026_forecast', '_actual|_forecast', ''),
#                 'mon_YYYY'
#             ),
#             CASE
#                 WHEN 'feb_2026_forecast' LIKE '%_actual' THEN 'actual'
#                 WHEN 'feb_2026_forecast' LIKE '%_forecast' THEN 'forecast'
#             END,
#             NULLIF(feb_2026_forecast, '')::numeric,
#             _airbyte_extracted_at
#         FROM tmp_business_health
#         WHERE NULLIF(feb_2026_forecast, '') IS NOT NULL
#         ON CONFLICT DO NOTHING;
#
#         INSERT INTO gist.business_health_long_format (
#             metric,
#             metric_month,
#             metric_type,
#             metric_value,
#             airbyte_extracted_at
#         )
#         SELECT
#             metrics,
#             TO_DATE(
#                 regexp_replace('jan_2026_forecast', '_actual|_forecast', ''),
#                 'mon_YYYY'
#             ),
#             CASE
#                 WHEN 'jan_2026_forecast' LIKE '%_actual' THEN 'actual'
#                 WHEN 'jan_2026_forecast' LIKE '%_forecast' THEN 'forecast'
#             END,
#             NULLIF(jan_2026_forecast, '')::numeric,
#             _airbyte_extracted_at
#         FROM tmp_business_health
#         WHERE NULLIF(jan_2026_forecast, '') IS NOT NULL
#         ON CONFLICT DO NOTHING;
#
#         INSERT INTO gist.business_health_long_format (
#             metric,
#             metric_month,
#             metric_type,
#             metric_value,
#             airbyte_extracted_at
#         )
#         SELECT
#             metrics,
#             TO_DATE(
#                 regexp_replace('mar_2026_forecast', '_actual|_forecast', ''),
#                 'mon_YYYY'
#             ),
#             CASE
#                 WHEN 'mar_2026_forecast' LIKE '%_actual' THEN 'actual'
#                 WHEN 'mar_2026_forecast' LIKE '%_forecast' THEN 'forecast'
#             END,
#             NULLIF(mar_2026_forecast, '')::numeric,
#             _airbyte_extracted_at
#         FROM tmp_business_health
#         WHERE NULLIF(mar_2026_forecast, '') IS NOT NULL
#         ON CONFLICT DO NOTHING;
#
#         INSERT INTO gist.business_health_long_format (
#             metric,
#             metric_month,
#             metric_type,
#             metric_value,
#             airbyte_extracted_at
#         )
#         SELECT
#             metrics,
#             TO_DATE(
#                 regexp_replace('nov_2025_forecast', '_actual|_forecast', ''),
#                 'mon_YYYY'
#             ),
#             CASE
#                 WHEN 'nov_2025_forecast' LIKE '%_actual' THEN 'actual'
#                 WHEN 'nov_2025_forecast' LIKE '%_forecast' THEN 'forecast'
#             END,
#             NULLIF(nov_2025_forecast, '')::numeric,
#             _airbyte_extracted_at
#         FROM tmp_business_health
#         WHERE NULLIF(nov_2025_forecast, '') IS NOT NULL
#         ON CONFLICT DO NOTHING;
#
#         INSERT INTO gist.business_health_long_format (
#             metric,
#             metric_month,
#             metric_type,
#             metric_value,
#             airbyte_extracted_at
#         )
#         SELECT
#             metrics,
#             TO_DATE(
#                 regexp_replace('oct_2025_forecast', '_actual|_forecast', ''),
#                 'mon_YYYY'
#             ),
#             CASE
#                 WHEN 'oct_2025_forecast' LIKE '%_actual' THEN 'actual'
#                 WHEN 'oct_2025_forecast' LIKE '%_forecast' THEN 'forecast'
#             END,
#             NULLIF(oct_2025_forecast, '')::numeric,
#             _airbyte_extracted_at
#         FROM tmp_business_health
#         WHERE NULLIF(oct_2025_forecast, '') IS NOT NULL
#         ON CONFLICT DO NOTHING;
#         "
# PL/pgSQL function gist.update_business_health_long_format() line 55 at EXECUTE
#
# Executing gist.update_client_escalations() at 2026-01-13 15:06:53.635759
# Completed gist.update_client_escalations() in 0.08 seconds
# Executing gist.update_gsc_tables() at 2026-01-13 15:07:04.040634
# Completed gist.update_gsc_tables() in 23.95 seconds
# Executing gist.update_gtm_campaign_campaigns() at 2026-01-13 15:07:38.326459
# Completed gist.update_gtm_campaign_campaigns() in 0.14 seconds
# Executing gist.update_gtm_campaign_sdr_info() at 2026-01-13 15:07:48.768953
# Completed gist.update_gtm_campaign_sdr_info() in 0.06 seconds
# Skipping procedure gist.update_gtm_master_allcampaigns()
# Executing gist.update_gush_seo_live_urls() at 2026-01-13 15:07:59.166853
# Completed gist.update_gush_seo_live_urls() in 0.11 seconds
# Executing gist.update_gush_seo_pages() at 2026-01-13 15:08:09.605023
# Completed gist.update_gush_seo_pages() in 0.16 seconds
# Executing gist.update_historic_allocation() at 2026-01-13 15:08:20.106594
# Completed gist.update_historic_allocation() in 0.96 seconds
# Executing gist.update_onboarded_clients() at 2026-01-13 15:08:31.386858
# Completed gist.update_onboarded_clients() in 0.09 seconds
#
# --- REFRESHING MATERIALIZED VIEWS ---
# Refreshing gist.matv_billablecampaigns at 2026-01-13 15:08:41.993568
# Refreshed gist.matv_billablecampaigns in 0.93 seconds
# Refreshing gist.matv_bot_contacts_master at 2026-01-13 15:08:48.231627
# Refreshed gist.matv_bot_contacts_master in 5.71 seconds
# Refreshing gist.matv_bot_hot_leads at 2026-01-13 15:08:59.266762
# Refreshed gist.matv_bot_hot_leads in 0.13 seconds
# Refreshing gist.matv_bot_outbound_calls at 2026-01-13 15:09:04.737593
# Refreshed gist.matv_bot_outbound_calls in 0.08 seconds
# Refreshing gist.matv_bot_sdr_info at 2026-01-13 15:09:10.184546
# Refreshed gist.matv_bot_sdr_info in 0.05 seconds
# Refreshing gist.matv_cluster_status_changes at 2026-01-13 15:09:15.539487
# Refreshed gist.matv_cluster_status_changes in 13.00 seconds
# Refreshing gist.matv_gist_campaignschecklistitems at 2026-01-13 15:09:33.852668
# Refreshed gist.matv_gist_campaignschecklistitems in 0.42 seconds
# Refreshing gist.matv_gist_clusterwriterwritten at 2026-01-13 15:09:39.632371
# Refreshed gist.matv_gist_clusterwriterwritten in 6.67 seconds
# Skipping refresh for gist.matv_gist_pageperformance
# Refreshing gist.matv_gist_pageperformancetrends at 2026-01-13 15:09:51.616718
# Refreshed gist.matv_gist_pageperformancetrends in 0.16 seconds
# Refreshing gist.matv_gtm_outbound_call_data at 2026-01-13 15:09:57.091188
# Refreshed gist.matv_gtm_outbound_call_data in 16.40 seconds
# Refreshing gist.matv_gtm_outbound_daily_split at 2026-01-13 15:10:18.826721
# Refreshed gist.matv_gtm_outbound_daily_split in 0.23 seconds
# Refreshing gist.matv_gush_seo_page_country_daily at 2026-01-13 15:10:24.378480
# Refreshed gist.matv_gush_seo_page_country_daily in 1.01 seconds
# Refreshing gist.matv_gush_seo_query_page_country_daily at 2026-01-13 15:10:30.720469
# Refreshed gist.matv_gush_seo_query_page_country_daily in 15.00 seconds
# Refreshing gist.matv_outbound_salesdialer_final_call_details at 2026-01-13 15:10:51.050850
# Refreshed gist.matv_outbound_salesdialer_final_call_details in 27.87 seconds
# Refreshing gist.matv_total_blogs_written at 2026-01-13 15:11:24.273049
# Refreshed gist.matv_total_blogs_written in 59.55 seconds
# Refreshing gist.matv_warm_leads_distinct_phones_updated at 2026-01-13 15:12:29.126829
# Refreshed gist.matv_warm_leads_distinct_phones_updated in 3.20 seconds
# Refreshing gist.matv_writer_page_metrics at 2026-01-13 15:12:37.632332
# Refreshed gist.matv_writer_page_metrics in 44.82 seconds
# Skipping refresh for gist.matv_writerallocation_contractedapproved_materialized
# Completed all executions at 2026-01-13 15:13:27.503852
